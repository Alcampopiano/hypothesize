# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data, trim_mean
from hypothesize.compare_groups_with_two_factors import spmcpa

# %%
df=create_example_data(6)
df.head()

# %%
results=spmcpa(2, 3, df, trim_mean, .2)

# %%
results['output']
