# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data, trim_mean
from hypothesize.compare_groups_with_single_factor import rmmcppb

# %%
df=create_example_data(3)
df.head()

# %%
results=rmmcppb(df, trim_mean, .2)

# %%
results['output']
