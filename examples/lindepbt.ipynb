# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data
from hypothesize.compare_groups_with_single_factor import lindepbt

# %%
df=create_example_data(3)
df.head()

# %%
results=lindepbt(df)

# %%
results['psihat']

# %%
results['test']
