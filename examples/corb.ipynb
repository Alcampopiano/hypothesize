# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data
from hypothesize.measuring_associations import corb, wincor

# %%
df=create_example_data(2)
df.head()

# %%
results=corb(wincor, df.cell_1, df.cell_2, .05, 1000, .2)

# %%
results
