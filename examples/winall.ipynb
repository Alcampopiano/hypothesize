# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data
from hypothesize.measuring_associations import winall

# %%
df=create_example_data(3)
df.head()

# %%
results=winall(df, tr=.2)

# %%
results['wcor']
# Out:
# array([[ 1.        ,  0.23237836,  0.05106066],
#        [ 0.23237836,  1.        , -0.12543308],
#        [ 0.05106066, -0.12543308,  1.        ]])
