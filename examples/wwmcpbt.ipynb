# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data
from hypothesize.compare_groups_with_two_factors import wwmcpbt

# %%
df=create_example_data(6)
df.head()

# %%
results=wwmcpbt(2, 3, df, .2)
# Out:
# ask wilcox if dif is supposed to be a argument here

# %%
results['factor_B']['test']
