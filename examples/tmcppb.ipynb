# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data, con1way, trim_mean
from hypothesize.compare_groups_with_single_factor import tmcppb

# %%
df=create_example_data(3)
df.head()
# Out:
#      cell_1    cell_2    cell_3
# 0  0.988089  0.531594  0.898677
# 1  0.040062  0.990704  0.393328
# 2  0.563470  0.395695  0.345625
# 3  0.856980  0.959441  0.168044
# 4  0.158802  0.391446  0.324284

# %%
results=tmcppb(df, trim_mean, .2)

# %%
results['output']
