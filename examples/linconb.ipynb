# %%
# !pip install hypothesize

# %%
from hypothesize.utilities import create_example_data, con1way
from hypothesize.compare_groups_with_single_factor import linconb

# %%
df=create_example_data(3)
df.head()

# %%
results=linconb(df, con1way(3))

# %%
results['psihat']

# %%
results['test']
